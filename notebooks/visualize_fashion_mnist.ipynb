# %%
# %cd ..

# %%
import argparse
import collections
import random
import pyro
import torch
import matplotlib.pyplot as plt
import numpy as np
import data_loader.data_loaders as module_data
import model.model as module_arch
from parse_config import ConfigParser
from trainer import Trainer

# %%
# %matplotlib inline

# %%
torch.autograd.set_detect_anomaly(True)

# %%
# fix random seeds for reproducibility
SEED = 123
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(SEED)
random.seed(SEED)

# %%
Args = collections.namedtuple('Args', 'config resume device')
config = ConfigParser.from_args(Args(config='fashion_mnist_config.json', resume=None, device=None))

# %%
logger = config.get_logger('train')

# %%
# setup data_loader instances
data_loader = config.init_obj('data_loader', module_data)
valid_data_loader = data_loader.split_validation()

# %%
# build model architecture, then print to console
model = config.init_obj('arch', module_arch)
model.draw()

# %%
model.resume_from_checkpoint('saved/models/FashionMnist_VaeCategory/0427_111527/model_best.pth')
model.eval()
# Out:
# VAECategoryModel(
#   (prior_0): StandardNormal()
#   (prior_1): StandardNormal()
#   (prior_2): StandardNormal()
#   (prior_3): StandardNormal()
#   (prior_4): StandardNormal()
#   (prior_5): StandardNormal()
#   (prior_6): StandardNormal()
#   (prior_7): StandardNormal()
#   (likelihood_0): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=64, out_features=456, bias=True)
#       (1): BatchNorm1d(456, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=456, out_features=784, bias=True)
#     )
#     (distribution): BernoulliObservation()
#   )
#   (likelihood_1): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=32, out_features=424, bias=True)
#       (1): BatchNorm1d(424, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=424, out_features=784, bias=True)
#     )
#     (distribution): BernoulliObservation()
#   )
#   (likelihood_2): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=128, out_features=520, bias=True)
#       (1): BatchNorm1d(520, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=520, out_features=784, bias=True)
#     )
#     (distribution): BernoulliObservation()
#   )
#   (likelihood_3): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=256, out_features=648, bias=True)
#       (1): BatchNorm1d(648, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=648, out_features=784, bias=True)
#     )
#     (distribution): BernoulliObservation()
#   )
#   (likelihood_4): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=512, out_features=904, bias=True)
#       (1): BatchNorm1d(904, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=904, out_features=784, bias=True)
#     )
#     (distribution): BernoulliObservation()
#   )
#   (likelihood_5): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=10, out_features=402, bias=True)
#       (1): BatchNorm1d(402, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=402, out_features=784, bias=True)
#     )
#     (distribution): BernoulliObservation()
#   )
#   (likelihood_6): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=16, out_features=408, bias=True)
#       (1): BatchNorm1d(408, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=408, out_features=784, bias=True)
#     )
#     (distribution): BernoulliObservation()
#   )
#   (latent_map_0): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=64, out_features=80, bias=True)
#       (1): BatchNorm1d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=80, out_features=32, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=32, out_features=64, bias=True)
#     )
#   )
#   (latent_map_1): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=64, out_features=128, bias=True)
#       (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=128, out_features=128, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=128, out_features=256, bias=True)
#     )
#   )
#   (latent_map_2): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=64, out_features=192, bias=True)
#       (1): BatchNorm1d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=192, out_features=256, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=256, out_features=512, bias=True)
#     )
#   )
#   (latent_map_3): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=64, out_features=320, bias=True)
#       (1): BatchNorm1d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=320, out_features=512, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=512, out_features=1024, bias=True)
#     )
#   )
#   (latent_map_4): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=64, out_features=69, bias=True)
#       (1): BatchNorm1d(69, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=69, out_features=10, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=10, out_features=20, bias=True)
#     )
#   )
#   (latent_map_5): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=64, out_features=72, bias=True)
#       (1): BatchNorm1d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=72, out_features=16, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=16, out_features=32, bias=True)
#     )
#   )
#   (latent_map_6): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=32, out_features=64, bias=True)
#       (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=64, out_features=64, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=64, out_features=128, bias=True)
#     )
#   )
#   (latent_map_7): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=32, out_features=96, bias=True)
#       (1): BatchNorm1d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=96, out_features=128, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=128, out_features=256, bias=True)
#     )
#   )
#   (latent_map_8): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=32, out_features=160, bias=True)
#       (1): BatchNorm1d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=160, out_features=256, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=256, out_features=512, bias=True)
#     )
#   )
#   (latent_map_9): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=32, out_features=288, bias=True)
#       (1): BatchNorm1d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=288, out_features=512, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=512, out_features=1024, bias=True)
#     )
#   )
#   (latent_map_10): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=32, out_features=37, bias=True)
#       (1): BatchNorm1d(37, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=37, out_features=10, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=10, out_features=20, bias=True)
#     )
#   )
#   (latent_map_11): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=32, out_features=40, bias=True)
#       (1): BatchNorm1d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=40, out_features=16, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=16, out_features=32, bias=True)
#     )
#   )
#   (latent_map_12): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=128, out_features=160, bias=True)
#       (1): BatchNorm1d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=160, out_features=64, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=64, out_features=128, bias=True)
#     )
#   )
#   (latent_map_13): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=128, out_features=144, bias=True)
#       (1): BatchNorm1d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=144, out_features=32, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=32, out_features=64, bias=True)
#     )
#   )
#   (latent_map_14): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=128, out_features=256, bias=True)
#       (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=256, out_features=512, bias=True)
#     )
#   )
#   (latent_map_15): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=128, out_features=384, bias=True)
#       (1): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=384, out_features=512, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=512, out_features=1024, bias=True)
#     )
#   )
#   (latent_map_16): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=128, out_features=133, bias=True)
#       (1): BatchNorm1d(133, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=133, out_features=10, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=10, out_features=20, bias=True)
#     )
#   )
#   (latent_map_17): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=128, out_features=136, bias=True)
#       (1): BatchNorm1d(136, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=136, out_features=16, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=16, out_features=32, bias=True)
#     )
#   )
#   (latent_map_18): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=256, out_features=288, bias=True)
#       (1): BatchNorm1d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=288, out_features=64, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=64, out_features=128, bias=True)
#     )
#   )
#   (latent_map_19): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=256, out_features=272, bias=True)
#       (1): BatchNorm1d(272, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=272, out_features=32, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=32, out_features=64, bias=True)
#     )
#   )
#   (latent_map_20): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=256, out_features=320, bias=True)
#       (1): BatchNorm1d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=320, out_features=128, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=128, out_features=256, bias=True)
#     )
#   )
#   (latent_map_21): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=256, out_features=512, bias=True)
#       (1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=512, out_features=512, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=512, out_features=1024, bias=True)
#     )
#   )
#   (latent_map_22): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=256, out_features=261, bias=True)
#       (1): BatchNorm1d(261, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=261, out_features=10, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=10, out_features=20, bias=True)
#     )
#   )
#   (latent_map_23): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=256, out_features=264, bias=True)
#       (1): BatchNorm1d(264, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=264, out_features=16, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=16, out_features=32, bias=True)
#     )
#   )
#   (latent_map_24): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=512, out_features=544, bias=True)
#       (1): BatchNorm1d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=544, out_features=64, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=64, out_features=128, bias=True)
#     )
#   )
#   (latent_map_25): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=512, out_features=528, bias=True)
#       (1): BatchNorm1d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=528, out_features=32, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=32, out_features=64, bias=True)
#     )
#   )
#   (latent_map_26): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=512, out_features=576, bias=True)
#       (1): BatchNorm1d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=576, out_features=128, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=128, out_features=256, bias=True)
#     )
#   )
#   (latent_map_27): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=512, out_features=640, bias=True)
#       (1): BatchNorm1d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=640, out_features=256, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=256, out_features=512, bias=True)
#     )
#   )
#   (latent_map_28): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=512, out_features=517, bias=True)
#       (1): BatchNorm1d(517, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=517, out_features=10, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=10, out_features=20, bias=True)
#     )
#   )
#   (latent_map_29): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=512, out_features=520, bias=True)
#       (1): BatchNorm1d(520, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=520, out_features=16, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=16, out_features=32, bias=True)
#     )
#   )
#   (latent_map_30): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=10, out_features=42, bias=True)
#       (1): BatchNorm1d(42, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=42, out_features=64, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=64, out_features=128, bias=True)
#     )
#   )
#   (latent_map_31): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=10, out_features=26, bias=True)
#       (1): BatchNorm1d(26, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=26, out_features=32, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=32, out_features=64, bias=True)
#     )
#   )
#   (latent_map_32): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=10, out_features=74, bias=True)
#       (1): BatchNorm1d(74, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=74, out_features=128, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=128, out_features=256, bias=True)
#     )
#   )
#   (latent_map_33): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=10, out_features=138, bias=True)
#       (1): BatchNorm1d(138, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=138, out_features=256, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=256, out_features=512, bias=True)
#     )
#   )
#   (latent_map_34): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=10, out_features=266, bias=True)
#       (1): BatchNorm1d(266, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=266, out_features=512, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=512, out_features=1024, bias=True)
#     )
#   )
#   (latent_map_35): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=10, out_features=18, bias=True)
#       (1): BatchNorm1d(18, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=18, out_features=16, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=16, out_features=32, bias=True)
#     )
#   )
#   (latent_map_36): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=16, out_features=48, bias=True)
#       (1): BatchNorm1d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=48, out_features=64, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=64, out_features=128, bias=True)
#     )
#   )
#   (latent_map_37): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=16, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=32, out_features=64, bias=True)
#     )
#   )
#   (latent_map_38): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=16, out_features=80, bias=True)
#       (1): BatchNorm1d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=80, out_features=128, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=128, out_features=256, bias=True)
#     )
#   )
#   (latent_map_39): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=16, out_features=144, bias=True)
#       (1): BatchNorm1d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=144, out_features=256, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=256, out_features=512, bias=True)
#     )
#   )
#   (latent_map_40): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=16, out_features=272, bias=True)
#       (1): BatchNorm1d(272, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=272, out_features=512, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=512, out_features=1024, bias=True)
#     )
#   )
#   (latent_map_41): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=16, out_features=21, bias=True)
#       (1): BatchNorm1d(21, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=21, out_features=10, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=10, out_features=20, bias=True)
#     )
#   )
#   (encoder_0): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=784, out_features=816, bias=True)
#       (1): BatchNorm1d(816, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=816, out_features=64, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=64, out_features=128, bias=True)
#     )
#   )
#   (encoder_1): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=784, out_features=800, bias=True)
#       (1): BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=800, out_features=32, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=32, out_features=64, bias=True)
#     )
#   )
#   (encoder_2): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=784, out_features=848, bias=True)
#       (1): BatchNorm1d(848, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=848, out_features=128, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=128, out_features=256, bias=True)
#     )
#   )
#   (encoder_3): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=784, out_features=912, bias=True)
#       (1): BatchNorm1d(912, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=912, out_features=256, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=256, out_features=512, bias=True)
#     )
#   )
#   (encoder_4): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=784, out_features=1040, bias=True)
#       (1): BatchNorm1d(1040, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=1040, out_features=512, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=512, out_features=1024, bias=True)
#     )
#   )
#   (encoder_5): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=784, out_features=789, bias=True)
#       (1): BatchNorm1d(789, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=789, out_features=10, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=10, out_features=20, bias=True)
#     )
#   )
#   (encoder_6): PathDensityNet(
#     (layer_0): Sequential(
#       (0): Linear(in_features=784, out_features=792, bias=True)
#       (1): BatchNorm1d(792, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=792, out_features=16, bias=True)
#     )
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=16, out_features=32, bias=True)
#     )
#   )
#   (guide_generator_confidence): Sequential(
#     (0): Linear(in_features=784, out_features=196, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=196, out_features=2, bias=True)
#     (3): Softplus(beta=1, threshold=20)
#   )
#   (guide_generator_weights): Sequential(
#     (0): Linear(in_features=784, out_features=196, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=196, out_features=64, bias=True)
#     (3): Softplus(beta=1, threshold=20)
#   )
#   (guide_latent_weights): Sequential(
#     (0): Linear(in_features=784, out_features=196, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=196, out_features=7, bias=True)
#     (3): Softplus(beta=1, threshold=20)
#   )
# )

# %%
validation_data = random.choice(list(valid_data_loader))[0]

# %%
prediction_data = model(observations=validation_data)

# %%
for k in np.random.randint(0, validation_data.shape[0], 10):
    image = validation_data[k].view(28, 28).detach().cpu().numpy()
    plt.title('Test image')
    plt.imshow(image)
    plt.show()

    prediction = prediction_data[k].view(28, 28).detach().cpu().numpy()
    plt.title('Reconstructed image')
    plt.imshow(prediction)
    plt.show()

# %%
for k in range(10):
    sample = model(None).view(28, 28).detach().cpu().numpy()
    plt.title('Sample from prior')
    plt.imshow(sample)
    plt.show()
