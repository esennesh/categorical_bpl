# %%
# %cd ..
# Out:
# /home/work/AnacondaProjects/categorical_bpl

# %%
import argparse
import collections
import random
import pyro
import torch
import matplotlib.pyplot as plt
import numpy as np
import data_loader.data_loaders as module_data
import model.model as module_arch
from parse_config import ConfigParser
from trainer import Trainer

# %%
# %matplotlib inline

# %%
torch.autograd.set_detect_anomaly(True)

# %%
# fix random seeds for reproducibility
SEED = 123
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(SEED)
random.seed(SEED)

# %%
Args = collections.namedtuple('Args', 'config resume device')
config = ConfigParser.from_args(Args(config='fashion_mnist_config.json', resume=None, device=None))

# %%
logger = config.get_logger('train')

# %%
# setup data_loader instances
data_loader = config.init_obj('data_loader', module_data)
valid_data_loader = data_loader.split_validation()

# %%
# build model architecture, then print to console
model = config.init_obj('arch', module_arch)
model.draw()

# %%
model.resume_from_checkpoint('saved/models/FashionMnist_VaeCategory/0523_135517/checkpoint-epoch120.pth')
model.eval()
# Out:
# VAECategoryModel(
#   (global_element_{R^64, 0}): StandardNormal()
#   (global_element_{R^128, 0}): StandardNormal()
#   (global_element_{R^256, 0}): StandardNormal()
#   (global_element_{R^512, 0}): StandardNormal()
#   (global_element_{R^784, 0}): StandardNormal()
#   (likelihood_0): PathDensityNet(
#     (residual_layer): Sequential(
#       (0): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): PReLU(num_parameters=1)
#       (2): Linear(in_features=64, out_features=456, bias=True)
#       (3): BatchNorm1d(456, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): PReLU(num_parameters=1)
#       (5): Linear(in_features=456, out_features=784, bias=True)
#     )
#     (identity_layer): Linear(in_features=64, out_features=784, bias=True)
#     (distribution): BernoulliObservation()
#   )
#   (likelihood_1): PathDensityNet(
#     (residual_layer): Sequential(
#       (0): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): PReLU(num_parameters=1)
#       (2): Linear(in_features=256, out_features=648, bias=True)
#       (3): BatchNorm1d(648, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): PReLU(num_parameters=1)
#       (5): Linear(in_features=648, out_features=784, bias=True)
#     )
#     (identity_layer): Linear(in_features=256, out_features=784, bias=True)
#     (distribution): BernoulliObservation()
#   )
#   (likelihood_2): PathDensityNet(
#     (residual_layer): Sequential(
#       (0): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): PReLU(num_parameters=1)
#       (2): Linear(in_features=128, out_features=520, bias=True)
#       (3): BatchNorm1d(520, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): PReLU(num_parameters=1)
#       (5): Linear(in_features=520, out_features=784, bias=True)
#     )
#     (identity_layer): Linear(in_features=128, out_features=784, bias=True)
#     (distribution): BernoulliObservation()
#   )
#   (likelihood_3): PathDensityNet(
#     (residual_layer): Sequential(
#       (0): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): PReLU(num_parameters=1)
#       (2): Linear(in_features=512, out_features=904, bias=True)
#       (3): BatchNorm1d(904, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): PReLU(num_parameters=1)
#       (5): Linear(in_features=904, out_features=784, bias=True)
#     )
#     (identity_layer): Linear(in_features=512, out_features=784, bias=True)
#     (distribution): BernoulliObservation()
#   )
#   (latent_map_0): PathDensityNet(
#     (residual_layer): Sequential(
#       (0): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): PReLU(num_parameters=1)
#       (2): Linear(in_features=64, out_features=192, bias=True)
#       (3): BatchNorm1d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): PReLU(num_parameters=1)
#       (5): Linear(in_features=192, out_features=256, bias=True)
#     )
#     (identity_layer): Linear(in_features=64, out_features=256, bias=True)
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=256, out_features=512, bias=True)
#     )
#   )
#   (latent_map_1): PathDensityNet(
#     (residual_layer): Sequential(
#       (0): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): PReLU(num_parameters=1)
#       (2): Linear(in_features=64, out_features=128, bias=True)
#       (3): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): PReLU(num_parameters=1)
#       (5): Linear(in_features=128, out_features=128, bias=True)
#     )
#     (identity_layer): Linear(in_features=64, out_features=128, bias=True)
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=128, out_features=256, bias=True)
#     )
#   )
#   (latent_map_2): PathDensityNet(
#     (residual_layer): Sequential(
#       (0): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): PReLU(num_parameters=1)
#       (2): Linear(in_features=64, out_features=320, bias=True)
#       (3): BatchNorm1d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): PReLU(num_parameters=1)
#       (5): Linear(in_features=320, out_features=512, bias=True)
#     )
#     (identity_layer): Linear(in_features=64, out_features=512, bias=True)
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=512, out_features=1024, bias=True)
#     )
#   )
#   (latent_map_3): PathDensityNet(
#     (residual_layer): Sequential(
#       (0): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): PReLU(num_parameters=1)
#       (2): Linear(in_features=256, out_features=288, bias=True)
#       (3): BatchNorm1d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): PReLU(num_parameters=1)
#       (5): Linear(in_features=288, out_features=64, bias=True)
#     )
#     (identity_layer): Linear(in_features=256, out_features=64, bias=True)
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=64, out_features=128, bias=True)
#     )
#   )
#   (latent_map_4): PathDensityNet(
#     (residual_layer): Sequential(
#       (0): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): PReLU(num_parameters=1)
#       (2): Linear(in_features=256, out_features=320, bias=True)
#       (3): BatchNorm1d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): PReLU(num_parameters=1)
#       (5): Linear(in_features=320, out_features=128, bias=True)
#     )
#     (identity_layer): Linear(in_features=256, out_features=128, bias=True)
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=128, out_features=256, bias=True)
#     )
#   )
#   (latent_map_5): PathDensityNet(
#     (residual_layer): Sequential(
#       (0): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): PReLU(num_parameters=1)
#       (2): Linear(in_features=256, out_features=512, bias=True)
#       (3): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): PReLU(num_parameters=1)
#       (5): Linear(in_features=512, out_features=512, bias=True)
#     )
#     (identity_layer): Linear(in_features=256, out_features=512, bias=True)
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=512, out_features=1024, bias=True)
#     )
#   )
#   (latent_map_6): PathDensityNet(
#     (residual_layer): Sequential(
#       (0): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): PReLU(num_parameters=1)
#       (2): Linear(in_features=128, out_features=160, bias=True)
#       (3): BatchNorm1d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): PReLU(num_parameters=1)
#       (5): Linear(in_features=160, out_features=64, bias=True)
#     )
#     (identity_layer): Linear(in_features=128, out_features=64, bias=True)
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=64, out_features=128, bias=True)
#     )
#   )
#   (latent_map_7): PathDensityNet(
#     (residual_layer): Sequential(
#       (0): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): PReLU(num_parameters=1)
#       (2): Linear(in_features=128, out_features=256, bias=True)
#       (3): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): PReLU(num_parameters=1)
#       (5): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (identity_layer): Linear(in_features=128, out_features=256, bias=True)
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=256, out_features=512, bias=True)
#     )
#   )
#   (latent_map_8): PathDensityNet(
#     (residual_layer): Sequential(
#       (0): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): PReLU(num_parameters=1)
#       (2): Linear(in_features=128, out_features=384, bias=True)
#       (3): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): PReLU(num_parameters=1)
#       (5): Linear(in_features=384, out_features=512, bias=True)
#     )
#     (identity_layer): Linear(in_features=128, out_features=512, bias=True)
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=512, out_features=1024, bias=True)
#     )
#   )
#   (latent_map_9): PathDensityNet(
#     (residual_layer): Sequential(
#       (0): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): PReLU(num_parameters=1)
#       (2): Linear(in_features=512, out_features=544, bias=True)
#       (3): BatchNorm1d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): PReLU(num_parameters=1)
#       (5): Linear(in_features=544, out_features=64, bias=True)
#     )
#     (identity_layer): Linear(in_features=512, out_features=64, bias=True)
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=64, out_features=128, bias=True)
#     )
#   )
#   (latent_map_10): PathDensityNet(
#     (residual_layer): Sequential(
#       (0): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): PReLU(num_parameters=1)
#       (2): Linear(in_features=512, out_features=640, bias=True)
#       (3): BatchNorm1d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): PReLU(num_parameters=1)
#       (5): Linear(in_features=640, out_features=256, bias=True)
#     )
#     (identity_layer): Linear(in_features=512, out_features=256, bias=True)
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=256, out_features=512, bias=True)
#     )
#   )
#   (latent_map_11): PathDensityNet(
#     (residual_layer): Sequential(
#       (0): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): PReLU(num_parameters=1)
#       (2): Linear(in_features=512, out_features=576, bias=True)
#       (3): BatchNorm1d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): PReLU(num_parameters=1)
#       (5): Linear(in_features=576, out_features=128, bias=True)
#     )
#     (identity_layer): Linear(in_features=512, out_features=128, bias=True)
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=128, out_features=256, bias=True)
#     )
#   )
#   (encoder_0): PathDensityNet(
#     (residual_layer): Sequential(
#       (0): BatchNorm1d(784, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): PReLU(num_parameters=1)
#       (2): Linear(in_features=784, out_features=816, bias=True)
#       (3): BatchNorm1d(816, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): PReLU(num_parameters=1)
#       (5): Linear(in_features=816, out_features=64, bias=True)
#     )
#     (identity_layer): Linear(in_features=784, out_features=64, bias=True)
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=64, out_features=128, bias=True)
#     )
#   )
#   (encoder_1): PathDensityNet(
#     (residual_layer): Sequential(
#       (0): BatchNorm1d(784, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): PReLU(num_parameters=1)
#       (2): Linear(in_features=784, out_features=912, bias=True)
#       (3): BatchNorm1d(912, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): PReLU(num_parameters=1)
#       (5): Linear(in_features=912, out_features=256, bias=True)
#     )
#     (identity_layer): Linear(in_features=784, out_features=256, bias=True)
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=256, out_features=512, bias=True)
#     )
#   )
#   (encoder_2): PathDensityNet(
#     (residual_layer): Sequential(
#       (0): BatchNorm1d(784, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): PReLU(num_parameters=1)
#       (2): Linear(in_features=784, out_features=848, bias=True)
#       (3): BatchNorm1d(848, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): PReLU(num_parameters=1)
#       (5): Linear(in_features=848, out_features=128, bias=True)
#     )
#     (identity_layer): Linear(in_features=784, out_features=128, bias=True)
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=128, out_features=256, bias=True)
#     )
#   )
#   (encoder_3): PathDensityNet(
#     (residual_layer): Sequential(
#       (0): BatchNorm1d(784, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): PReLU(num_parameters=1)
#       (2): Linear(in_features=784, out_features=1040, bias=True)
#       (3): BatchNorm1d(1040, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): PReLU(num_parameters=1)
#       (5): Linear(in_features=1040, out_features=512, bias=True)
#     )
#     (identity_layer): Linear(in_features=784, out_features=512, bias=True)
#     (distribution): DiagonalGaussian(
#       (parameterization): Linear(in_features=512, out_features=1024, bias=True)
#     )
#   )
#   (guide_embedding): Sequential(
#     (0): Linear(in_features=784, out_features=49, bias=True)
#     (1): BatchNorm1d(49, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): PReLU(num_parameters=1)
#   )
#   (guide_confidences): Sequential(
#     (0): Linear(in_features=49, out_features=2, bias=True)
#     (1): Softplus(beta=1, threshold=20)
#   )
#   (guide_navigator): GRUCell(5, 49)
#   (guide_navigation_decoder): Sequential(
#     (0): Linear(in_features=49, out_features=5, bias=True)
#     (1): Softplus(beta=1, threshold=20)
#   )
# )

# %%
validation_data = random.choice(list(valid_data_loader))[0]

# %%
path, latents, prediction_data = model(observations=validation_data)

# %%
model.draw(path)

# %%
for k in np.random.randint(0, validation_data.shape[0], 10):
    image = validation_data[k].view(28, 28).detach().cpu().numpy()
    plt.title('Test image')
    plt.imshow(image)
    plt.show()

    prediction = prediction_data[k].view(28, 28).detach().cpu().numpy()
    plt.title('Reconstructed image')
    plt.imshow(prediction)
    plt.show()

# %%
for k in range(10):
    path, latents, sample = model(None)
    sample = sample.view(28, 28).detach().cpu().numpy()
    model.draw(path)
    plt.show()

    plt.title('Sample from prior')
    plt.imshow(sample)
    plt.show()
