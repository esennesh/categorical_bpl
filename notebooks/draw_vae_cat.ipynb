# %%
# %cd ..
# Out:
# /home/work/AnacondaProjects/categorical_bpl

# %%
import torch
import model.model as model

# %%
# %matplotlib inline

# %%
vae_cat = model.VAECategoryModel()

# %%
vae_cat.draw()
